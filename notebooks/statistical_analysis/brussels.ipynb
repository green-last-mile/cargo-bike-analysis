# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Brussels Cargo Bike Analysis

# %%
import os
import sys
from pathlib import Path

# add the
ROOT = Path(os.getcwd())
while not (ROOT / ".git").exists():
    ROOT = ROOT.parent

sys.path.append(str(ROOT))

from src.config import CargoBikeConfig, load_config

import polars as pl
import geopandas as gpd
import pandas as pd

# %% [markdown]
# ## Open the Files

# %%
config = load_config(ROOT / "config" / "paper.yaml")

brussel_config = CargoBikeConfig.get_service_time_city(config, "brussels")

# brussel_config

# %% [markdown]
# ### Open the H3 File

# %%
h3_df = (
    pd.concat([gpd.read_parquet(city.h3_file).assign(city=city.name) for city in config.Cities], axis=0)
    .query("is_city")
)

h3_df.head()
# Out:
#                                                           geometry  is_city  \
# region_id
# 892a339a5afffff  POLYGON ((-71.13572 42.23376, -71.13794 42.232...     True
# 892a3066a3bffff  POLYGON ((-71.08114 42.30902, -71.08337 42.308...     True
# 892a302a567ffff  POLYGON ((-70.82381 42.36269, -70.82604 42.361...     True
# 892a3066e17ffff  POLYGON ((-71.06072 42.33323, -71.06295 42.332...     True
# 892a3066b3bffff  POLYGON ((-71.06614 42.29023, -71.06837 42.289...     True
#
#                         city
# region_id
# 892a339a5afffff  Boston, USA
# 892a3066a3bffff  Boston, USA
# 892a302a567ffff  Boston, USA
# 892a3066e17ffff  Boston, USA
# 892a3066b3bffff  Boston, USA

# %%
service_time_df = pl.read_parquet(brussel_config.file)

service_time_df.head()
# Out:
# shape: (5, 9)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ total_sto ┆ predicted ┆ predicted ┆ region_id ┆ … ┆ rider     ┆ gps_stop_ ┆ gps_start ┆ package_ │
# │ p_time    ┆ _service_ ┆ _service_ ┆ ---       ┆   ┆ ---       ┆ time      ┆ _time     ┆ number   │
# │ ---       ┆ time      ┆ time_95th ┆ str       ┆   ┆ u64       ┆ ---       ┆ ---       ┆ ---      │
# │ i64       ┆ ---       ┆ ---       ┆           ┆   ┆           ┆ datetime[ ┆ datetime[ ┆ i64      │
# │           ┆ f64       ┆ f64       ┆           ┆   ┆           ┆ ns, UTC]  ┆ ns, UTC]  ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 243       ┆ 159.28940 ┆ 210.44563 ┆ 891fa4418 ┆ … ┆ 132582696 ┆ 2022-10-2 ┆ 2022-10-2 ┆ 2        │
# │           ┆ 8         ┆ 7         ┆ 6fffff    ┆   ┆ 575674549 ┆ 9         ┆ 9         ┆          │
# │           ┆           ┆           ┆           ┆   ┆ 6         ┆ 08:33:50  ┆ 08:37:53  ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆ UTC       ┆ UTC       ┆          │
# │ 185       ┆ 119.40631 ┆ 154.25696 ┆ 891fa441b ┆ … ┆ 132582696 ┆ 2022-10-2 ┆ 2022-10-2 ┆ 1        │
# │           ┆ 9         ┆ 6         ┆ 53ffff    ┆   ┆ 575674549 ┆ 9         ┆ 9         ┆          │
# │           ┆           ┆           ┆           ┆   ┆ 6         ┆ 08:58:41  ┆ 09:01:46  ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆ UTC       ┆ UTC       ┆          │
# │ 440       ┆ 290.28656 ┆ 390.51613 ┆ 891fa441b ┆ … ┆ 132582696 ┆ 2022-10-2 ┆ 2022-10-2 ┆ 1        │
# │           ┆ 5         ┆ 6         ┆ dbffff    ┆   ┆ 575674549 ┆ 9         ┆ 9         ┆          │
# │           ┆           ┆           ┆           ┆   ┆ 6         ┆ 09:04:26  ┆ 09:11:46  ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆ UTC       ┆ UTC       ┆          │
# │ 197       ┆ 132.54048 ┆ 173.54222 ┆ 891fa441b ┆ … ┆ 132582696 ┆ 2022-10-2 ┆ 2022-10-2 ┆ 1        │
# │           ┆ 1         ┆ 1         ┆ 83ffff    ┆   ┆ 575674549 ┆ 9         ┆ 9         ┆          │
# │           ┆           ┆           ┆           ┆   ┆ 6         ┆ 09:18:46  ┆ 09:22:03  ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆ UTC       ┆ UTC       ┆          │
# │ 340       ┆ 218.07918 ┆ 296.74687 ┆ 891fa44ad ┆ … ┆ 132582696 ┆ 2022-10-3 ┆ 2022-10-3 ┆ 2        │
# │           ┆ 4         ┆ 2         ┆ 0fffff    ┆   ┆ 575674549 ┆ 1         ┆ 1         ┆          │
# │           ┆           ┆           ┆           ┆   ┆ 6         ┆ 05:59:34  ┆ 06:05:14  ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆ UTC       ┆ UTC       ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
service_time_df = service_time_df.filter(
    pl.col('region_id').is_in(h3_df.index.to_list())
)

# %% [markdown]
# ## Summary

# %%
service_time_df['gps_stop_time'].min().isoformat(), service_time_df['gps_stop_time'].max().isoformat()
# Out:
# ('2022-10-29T08:33:50+00:00', '2023-09-30T09:37:55+00:00')

# %%
len(service_time_df.select(
    pl.col("rider"),
    pl.col("gps_stop_time").dt.date()
).unique())
# Out:
# 786

# %%
service_time_df.shape[0]
# Out:
# 10847

# %%
from srai.plotting import plot_numeric_data
from srai.h3 import h3_to_shapely_geometry
from srai.constants import WGS84_CRS, REGIONS_INDEX
import geopandas as gpd

# %%
grouped_df = service_time_df.to_pandas().rename({'h3': REGIONS_INDEX}, axis=1).groupby(REGIONS_INDEX).agg(
    {'predicted_service_time': 'count'}
)


gdf = gpd.GeoDataFrame(
    grouped_df,
    geometry=h3_to_shapely_geometry(grouped_df.index),
    crs=WGS84_CRS
)

gdf.head()
# Out:
#                  predicted_service_time  \
# region_id
# 891fa440003ffff                       1
# 891fa440027ffff                       1
# 891fa44003bffff                       1
# 891fa440047ffff                       1
# 891fa44004bffff                       2
#
#                                                           geometry
# region_id
# 891fa440003ffff  POLYGON ((4.32648 50.89679, 4.32680 50.89518, ...
# 891fa440027ffff  POLYGON ((4.34322 50.89668, 4.34355 50.89506, ...
# 891fa44003bffff  POLYGON ((4.33393 50.89536, 4.33426 50.89374, ...
# 891fa440047ffff  POLYGON ((4.32281 50.89128, 4.32314 50.88966, ...
# 891fa44004bffff  POLYGON ((4.31634 50.88785, 4.31667 50.88623, ...

# %%
m = plot_numeric_data(gdf, data_column='predicted_service_time', )
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2c5c36cb8067732526d918c8b2faabd8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2c5c36cb8067732526d918c8b2faabd8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2c5c36cb8067732526d918c8b2faabd8 = L.map(
#                 &quot;map_2c5c36cb8067732526d918c8b2faabd8&quot;,
#                 {
#                     center: [50.839037972921574, 4.363190384664697],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_2c5c36cb8067732526d918c8b2faabd8);
#
#
#
#
#
#             var tile_layer_c1098e1af514cc3e945d0029a8f3ef19 = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2c5c36cb8067732526d918c8b2faabd8);
#
#
#             map_2c5c36cb8067732526d918c8b2faabd8.fitBounds(
#                 [[50.76945283558497, 4.256705333854175], [50.90862311025818, 4.469675435475219]],
#                 {}
#             );
#
#
#         function geo_json_eebdbc7dab759d7b7623ff6746a7da9e_styler(feature) {
#             switch(feature.id) {
#                 case &quot;4&quot;: case &quot;7&quot;: case &quot;8&quot;: case &quot;11&quot;: case &quot;22&quot;: case &quot;25&quot;: case &quot;26&quot;: case &quot;33&quot;: case &quot;34&quot;: case &quot;35&quot;: case &quot;38&quot;: case &quot;57&quot;: case &quot;58&quot;: case &quot;62&quot;: case &quot;67&quot;: case &quot;73&quot;: case &quot;85&quot;: case &quot;86&quot;: case &quot;87&quot;: case &quot;98&quot;: case &quot;99&quot;: case &quot;107&quot;: case &quot;113&quot;: case &quot;117&quot;: case &quot;118&quot;: case &quot;120&quot;: case &quot;123&quot;: case &quot;131&quot;: case &quot;132&quot;: case &quot;139&quot;: case &quot;141&quot;: case &quot;145&quot;: case &quot;146&quot;: case &quot;147&quot;: case &quot;150&quot;: case &quot;159&quot;: case &quot;161&quot;: case &quot;162&quot;: case &quot;163&quot;: case &quot;173&quot;: case &quot;224&quot;: case &quot;235&quot;: case &quot;244&quot;: case &quot;250&quot;: case &quot;253&quot;: case &quot;304&quot;: case &quot;356&quot;: case &quot;367&quot;: case &quot;370&quot;: case &quot;375&quot;: case &quot;379&quot;: case &quot;386&quot;: case &quot;387&quot;: case &quot;408&quot;: case &quot;417&quot;: case &quot;433&quot;: case &quot;447&quot;: case &quot;448&quot;: case &quot;461&quot;: case &quot;474&quot;: case &quot;482&quot;: case &quot;485&quot;: case &quot;487&quot;: case &quot;488&quot;: case &quot;492&quot;: case &quot;500&quot;: case &quot;501&quot;: case &quot;502&quot;: case &quot;515&quot;: case &quot;530&quot;: case &quot;537&quot;: case &quot;541&quot;: case &quot;563&quot;: case &quot;567&quot;: case &quot;572&quot;: case &quot;580&quot;: case &quot;586&quot;: case &quot;588&quot;: case &quot;606&quot;: case &quot;607&quot;: case &quot;609&quot;: case &quot;612&quot;: case &quot;613&quot;: case &quot;623&quot;: case &quot;627&quot;: case &quot;628&quot;: case &quot;634&quot;: case &quot;636&quot;: case &quot;643&quot;: case &quot;644&quot;: case &quot;648&quot;: case &quot;652&quot;: case &quot;656&quot;: case &quot;657&quot;: case &quot;658&quot;: case &quot;662&quot;: case &quot;665&quot;: case &quot;669&quot;: case &quot;671&quot;: case &quot;676&quot;: case &quot;679&quot;: case &quot;692&quot;: case &quot;706&quot;: case &quot;745&quot;: case &quot;746&quot;: case &quot;751&quot;: case &quot;752&quot;: case &quot;757&quot;: case &quot;760&quot;: case &quot;761&quot;: case &quot;762&quot;: case &quot;763&quot;: case &quot;767&quot;: case &quot;768&quot;: case &quot;780&quot;: case &quot;781&quot;: case &quot;784&quot;: case &quot;785&quot;: case &quot;789&quot;: case &quot;793&quot;: case &quot;794&quot;: case &quot;796&quot;: case &quot;843&quot;: case &quot;844&quot;: case &quot;857&quot;: case &quot;858&quot;: case &quot;870&quot;: case &quot;875&quot;: case &quot;876&quot;: case &quot;877&quot;: case &quot;878&quot;: case &quot;880&quot;: case &quot;887&quot;:
#                     return {&quot;color&quot;: &quot;#444&quot;, &quot;fillColor&quot;: &quot;#fcdd9bff&quot;, &quot;fillOpacity&quot;:

# %%
import math

circle = gpd.GeoSeries(gdf.to_crs(gdf.estimate_utm_crs()).unary_union, crs=gdf.estimate_utm_crs()).minimum_bounding_circle()

area = circle.area / 10 ** 6

# get the radius
radius = (area / math.pi) ** 0.5

radius
# Out:
# 0    8.133241
# dtype: float64

# %%
circle.to_crs(WGS84_CRS).explore(m=m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2c5c36cb8067732526d918c8b2faabd8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2c5c36cb8067732526d918c8b2faabd8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2c5c36cb8067732526d918c8b2faabd8 = L.map(
#                 &quot;map_2c5c36cb8067732526d918c8b2faabd8&quot;,
#                 {
#                     center: [50.839037972921574, 4.363190384664697],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_2c5c36cb8067732526d918c8b2faabd8);
#
#
#
#
#
#             var tile_layer_c1098e1af514cc3e945d0029a8f3ef19 = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2c5c36cb8067732526d918c8b2faabd8);
#
#
#             map_2c5c36cb8067732526d918c8b2faabd8.fitBounds(
#                 [[50.76945283558497, 4.256705333854175], [50.90862311025818, 4.469675435475219]],
#                 {}
#             );
#
#
#         function geo_json_eebdbc7dab759d7b7623ff6746a7da9e_styler(feature) {
#             switch(feature.id) {
#                 case &quot;4&quot;: case &quot;7&quot;: case &quot;8&quot;: case &quot;11&quot;: case &quot;22&quot;: case &quot;25&quot;: case &quot;26&quot;: case &quot;33&quot;: case &quot;34&quot;: case &quot;35&quot;: case &quot;38&quot;: case &quot;57&quot;: case &quot;58&quot;: case &quot;62&quot;: case &quot;67&quot;: case &quot;73&quot;: case &quot;85&quot;: case &quot;86&quot;: case &quot;87&quot;: case &quot;98&quot;: case &quot;99&quot;: case &quot;107&quot;: case &quot;113&quot;: case &quot;117&quot;: case &quot;118&quot;: case &quot;120&quot;: case &quot;123&quot;: case &quot;131&quot;: case &quot;132&quot;: case &quot;139&quot;: case &quot;141&quot;: case &quot;145&quot;: case &quot;146&quot;: case &quot;147&quot;: case &quot;150&quot;: case &quot;159&quot;: case &quot;161&quot;: case &quot;162&quot;: case &quot;163&quot;: case &quot;173&quot;: case &quot;224&quot;: case &quot;235&quot;: case &quot;244&quot;: case &quot;250&quot;: case &quot;253&quot;: case &quot;304&quot;: case &quot;356&quot;: case &quot;367&quot;: case &quot;370&quot;: case &quot;375&quot;: case &quot;379&quot;: case &quot;386&quot;: case &quot;387&quot;: case &quot;408&quot;: case &quot;417&quot;: case &quot;433&quot;: case &quot;447&quot;: case &quot;448&quot;: case &quot;461&quot;: case &quot;474&quot;: case &quot;482&quot;: case &quot;485&quot;: case &quot;487&quot;: case &quot;488&quot;: case &quot;492&quot;: case &quot;500&quot;: case &quot;501&quot;: case &quot;502&quot;: case &quot;515&quot;: case &quot;530&quot;: case &quot;537&quot;: case &quot;541&quot;: case &quot;563&quot;: case &quot;567&quot;: case &quot;572&quot;: case &quot;580&quot;: case &quot;586&quot;: case &quot;588&quot;: case &quot;606&quot;: case &quot;607&quot;: case &quot;609&quot;: case &quot;612&quot;: case &quot;613&quot;: case &quot;623&quot;: case &quot;627&quot;: case &quot;628&quot;: case &quot;634&quot;: case &quot;636&quot;: case &quot;643&quot;: case &quot;644&quot;: case &quot;648&quot;: case &quot;652&quot;: case &quot;656&quot;: case &quot;657&quot;: case &quot;658&quot;: case &quot;662&quot;: case &quot;665&quot;: case &quot;669&quot;: case &quot;671&quot;: case &quot;676&quot;: case &quot;679&quot;: case &quot;692&quot;: case &quot;706&quot;: case &quot;745&quot;: case &quot;746&quot;: case &quot;751&quot;: case &quot;752&quot;: case &quot;757&quot;: case &quot;760&quot;: case &quot;761&quot;: case &quot;762&quot;: case &quot;763&quot;: case &quot;767&quot;: case &quot;768&quot;: case &quot;780&quot;: case &quot;781&quot;: case &quot;784&quot;: case &quot;785&quot;: case &quot;789&quot;: case &quot;793&quot;: case &quot;794&quot;: case &quot;796&quot;: case &quot;843&quot;: case &quot;844&quot;: case &quot;857&quot;: case &quot;858&quot;: case &quot;870&quot;: case &quot;875&quot;: case &quot;876&quot;: case &quot;877&quot;: case &quot;878&quot;: case &quot;880&quot;: case &quot;887&quot;:
#                     return {&quot;color&quot;: &quot;#444&quot;, &quot;fillColor&quot;: &quot;#fcdd9bff&quot;, &quot;fillOpacity&quot;:
